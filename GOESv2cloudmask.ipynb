# %% [markdown]
# ## FIJARSE EN LA REGION GEOGRAFICA DE INTERES

# %%
import xarray as xr
import numpy as np
import datetime 
import numpy as np
import mpmath as mp
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import copy
from sklearn.preprocessing import StandardScaler
# %matplotlib qt

from matplotlib.dates import DayLocator, HourLocator, DateFormatter, drange
import os 
from os import listdir
from os.path import isfile, join

# %%
"get directory 2.0"

def get_directory_contents(folder):
    items = os.listdir(folder)
    files = [item for item in items if os.path.isfile(os.path.join(folder, item))]
    folders = [item for item in items if os.path.isdir(os.path.join(folder, item))]
    
    return {'files': files, 'folders': folders}

# %% [markdown]
# ### ITERATION

# %%
#path_general="C:/Users/enclab01/Desktop/THESIS/Datos Satelitales/goes/second iteration/09 septiembre 2022"
#path_general="C:/Users/enclab01/Desktop/THESIS/Datos Satelitales/goes/second iteration/agosto 2022"
#path_general="C:/Users/enclab01/Desktop/THESIS/Datos Satelitales/goes/eventos de la jolla"
#path_general="C:/Users/enclab01/Desktop/THESIS/Datos Satelitales/goes/resto de dias la jolla"
#path_general="C:/Users/enclab01/Desktop/THESIS/Datos Satelitales/goes/second iteration/sas1"
#path_general="C:/Users/enclab01/Desktop/THESIS/Datos Satelitales/goes/second iteration/sas2"
path_general="C:/Users/enclab01/Desktop/THESIS/Datos Satelitales/goes/diaslajollacloudmask"

contents = get_directory_contents(path_general)
subfolders=contents['folders']

newlistt=[]
for item in subfolders:
    newlistt.append(path_general+'/'+str(item))

print(subfolders)
print(newlistt)
# Out:
# ['8351532853', '8351532854', '8351532855', '8351532856', '8351532858', '8351533308', '8351533713', '8351533873', '8351533874', '8351533893', '8351533894', '8351533895', '8351533896', '8351533897', '8351533898', '8351534086', '8351534248', '8351534249', '8351534250', '8351534251']
# ['C:/Users/enclab01/Desktop/THESIS/Datos Satelitales/goes/diaslajollacloudmask/8351532853', 'C:/Users/enclab01/Desktop/THESIS/Datos Satelitales/goes/diaslajollacloudmask/8351532854', 'C:/Users/enclab01/Desktop/THESIS/Datos Satelitales/goes/diaslajollacloudmask/8351532855', 'C:/Users/enclab01/Desktop/THESIS/Datos Satelitales/goes/diaslajollacloudmask/8351532856', 'C:/Users/enclab01/Desktop/THESIS/Datos Satelitales/goes/diaslajollacloudmask/8351532858', 'C:/Users/enclab01/Desktop/THESIS/Datos Satelitales/goes/diaslajollacloudmask/8351533308', 'C:/Users/enclab01/Desktop/THESIS/Datos Satelitales/goes/diaslajollacloudmask/8351533713', 'C:/Users/enclab01/Desktop/THESIS/Datos Satelitales/goes/diaslajollacloudmask/8351533873', 'C:/Users/enclab01/Desktop/THESIS/Datos Satelitales/goes/diaslajollacloudmask/8351533874', 'C:/Users/enclab01/Desktop/THESIS/Datos Satelitales/goes/diaslajollacloudmask/8351533893', 'C:/Users/enclab01/Desktop/THESIS/Datos Satelitales/goes/diaslajollacloudmask/8351533894', 'C:/Users/enclab01/Desktop/THESIS/Datos Satelitales/goes/diaslajollacloudmask/8351533895', 'C:/Users/enclab01/Desktop/THESIS/Datos Satelitales/goes/diaslajollacloudmask/8351533896', 'C:/Users/enclab01/Desktop/THESIS/Datos Satelitales/goes/diaslajollacloudmask/8351533897', 'C:/Users/enclab01/Desktop/THESIS/Datos Satelitales/goes/diaslajollacloudmask/8351533898', 'C:/Users/enclab01/Desktop/THESIS/Datos Satelitales/goes/diaslajollacloudmask/8351534086', 'C:/Users/enclab01/Desktop/THESIS/Datos Satelitales/goes/diaslajollacloudmask/8351534248', 'C:/Users/enclab01/Desktop/THESIS/Datos Satelitales/goes/diaslajollacloudmask/8351534249', 'C:/Users/enclab01/Desktop/THESIS/Datos Satelitales/goes/diaslajollacloudmask/8351534250', 'C:/Users/enclab01/Desktop/THESIS/Datos Satelitales/goes/diaslajollacloudmask/8351534251']

# %% [markdown]
# FUNCION PRINCIPAL

# %%
import GOES

def satellitedata(indice,newlist):

    BCM_values=[]
    timeBCM=[]

    DQF_values=[]
    timeDQF=[]

     #for i in np.arange(1,2):
    for i in np.arange(0,len(newlist)):   
        
        try:
            'Cloud mask'
            ds = GOES.open_dataset(newlist[i])
    
            BCM, LonCen, LatCen = ds.image('BCM', lonlat='center')
            
            #x, y = GOES.find_pixel_of_coordinate(LonCen, LatCen, -119.5, 33.2) #San Nicolas Island
            #x, y = GOES.find_pixel_of_coordinate(LonCen, LatCen, -121.8, 36.3) #Point Sur
            x, y = GOES.find_pixel_of_coordinate(LonCen, LatCen, -117.23, 32.88) #La jolla
            
            'DQF'
            DQF, LonCen, LatCen = ds.image('DQF', lonlat='center')
            
       
            BCM_values.append(BCM.data[y,x])
            DQF_values.append(DQF.data[y,x])
            timeBCM.append(BCM.time_bounds.data[0])
            timeDQF.append(DQF.time_bounds.data[0])
    
            
        
        except:
            BCM_values.append(np.nan)
            DQF_values.append(np.nan)
            timeBCM.append(np.nan)
            timeDQF.append(np.nan)
            
            
            
    'Saving data'
     #print(timeBCM)
     #print(BCM_values)
     #print(BCM_deviations)
     #print(DQF_values)
     #print(DQF_deviations)
    
    a1={'Dates_and_Hours':  timeBCM, 'BCM': BCM_values, 'DQF':DQF_values}
    data_of_that_day= pd.DataFrame (a1, columns = ['Dates_and_Hours','BCM','DQF'])
    print(data_of_that_day)
    
    if indice<10:
        data_of_that_day.to_csv('Mes'+str(0)+str(indice+1)+".txt", index=False, sep='\t')
    else:
        data_of_that_day.to_csv('Mes'+str(indice+1)+".txt", index=False, sep='\t')
        
        
    return

# %%
#for i in np.arange(len(newlistt)-1,len(newlistt)):
for i in np.arange(0,len(newlistt)):
#for i in np.arange(0,1):    
    path_new=newlistt[i]+"/"+"001"
    print(path_new)
    contents_subfolder = get_directory_contents(path_new)
    
    singlefiles=contents_subfolder['files']
    
    
    
    finalpaths=[]
    for j in np.arange(0,len(singlefiles)):
        finalpaths.append(path_new+"/"+singlefiles[j])
        
            
    satellitedata(i,finalpaths)
# Out:
# C:/Users/enclab01/Desktop/THESIS/Datos Satelitales/goes/diaslajollacloudmask/8351532853/001
#                Dates_and_Hours  BCM  DQF
# 0   2021-01-26 00:01:17.707871  1.0  0.0
# 1   2021-01-26 00:06:17.707819  1.0  0.0
# 2   2021-01-26 00:11:17.707769  1.0  0.0
# 3   2021-01-26 00:16:17.707722  1.0  0.0
# 4   2021-01-26 00:21:17.707678  1.0  0.0
# ..                         ...  ...  ...
# 495 2021-01-27 19:01:17.688581  0.0  0.0
# 496 2021-01-27 19:06:17.688577  0.0  0.0
# 497 2021-01-27 19:11:17.688574  0.0  0.0
# 498 2021-01-27 19:16:17.688572  0.0  0.0
# 499 2021-01-27 19:21:17.690374  0.0  0.0
#
# [500 rows x 3 columns]
# C:/Users/enclab01/Desktop/THESIS/Datos Satelitales/goes/diaslajollacloudmask/8351532854/001
#               Dates_and_Hours  BCM  DQF
# 0  2021-01-27 19:26:17.690373  0.0  0.0
# 1  2021-01-27 19:31:17.690371  0.0  0.0
# 2  2021-01-27 19:36:17.690370  0.0  0.0
# 3  2021-01-27 19:41:17.690368  0.0  0.0
# 4  2021-01-27 19:46:17.692168  0.0  0.0
# 5  2021-01-27 19:51:17.692165  0.0  0.0
# 6  2021-01-27 19:56:17.692160  0.0  0.0
# 7  2021-01-27 20:01:17.692155  0.0  0.0
# 8  2021-01-27 20:06:17.692147  0.0  0.0
# 9  2021-01-27 20:11:17.693942  0.0  0.0
# 10 2021-01-27 20:16:17.693931  0.0  0.0
# 11 2021-01-27 20:21:17.693918  0.0  0.0
# 12 2021-01-27 20:26:17.693903  0.0  0.0
# 13 2021-01-27 20:31:17.693886  0.0  0.0
# 14 2021-01-27 20:36:17.695670  0.0  0.0
# 15 2021-01-27 20:41:17.695647  0.0  0.0
# 16 2021-01-27 20:46:17.695622  0.0  0.0
# 17 2021-01-27 20:51:17.695594  0.0  0.0
# 18 2021-01-27 20:56:17.695563  0.0  0.0
# 19 2021-01-27 21:01:17.695529  0.0  0.0
# 20 2021-01-27 21:06:17.697294  0.0  0.0
# 21 2021-01-27 21:11:17.697253  0.0  0.0
# 22 2021-01-27 21:16:17.697208  0.0  0.0
# 23 2021-01-27 21:21:17.697159  0.0  0.0
# 24 2021-01-27 21:26:17.697107  0.0  0.0
# 25 2021-01-27 21:31:17.698854  0.0  0.0
# 26 2021-01-27 21:36:17.698793  0.0  0.0
# 27 2021-01-27 21:41:17.698729  0.0  0.0
# 28 2021-01-27 21:46:17.698661  0.0  0.0
# 29 2021-01-27 21:51:17.698589  0.0  0.0
# 30 2021-01-27 21:56:17.700318  0.0  0.0
# 31 2021-01-27 22:01:17.700242  0.0  0.0
# 32 2021-01-27 22:06:17.700163  0.0  0.0
# 33 2021-01-27 22:11:17.700082  0.0  0.0
# 34 2021-01-27 22:16:17.699998  0.0  0.0
# 35 2021-01-27 22:21:17.701716  0.0  0.0
# 36 2021-01-27 22:26:17.701629  0.0  0.0
# 37 2021-01-27 22:31:17.701541  0.0  0.0
# 38 2021-01-27 22:36:17.701451  0.0  0.0
# 39 2021-01-27 22:41:17.701359  0.0  0.0
# 40 2021-01-27 22:46:17.703070  0.0  0.0
# 41 2021-01-27 22:51:17.702975  0.0  0.0
# 42 2021-01-27 22:56:17.702880  0.0  0.0
# 43 2021-01-27 23:01:17.702782  0.0  0.0
# 44 2021-01-27 23:06:17.702683  0.0  0.0
# 45 2021-01-27 23:11:17.702582  0.0  0.0
# 46 2021-01-27 23:16:17.704283  0.0  0.0
# 47 2021-01-27 23:21:17.704180  0.0  0.0
# 48 2021-01-27 23:26:17.704078  0.0  0.0
# 49 2021-01-27 23:31:17.703975  0.0  0.0
# 50 2021-01-27 23:36:17.703873  0.0  0.0
# 51 2021-01-27 23:41:17.705574  0.0  0.0
# 52 2021-01-27 23:46:17.705472  0.0  0.0
# 53 2021-01-27 23:51:17.705371  0.0  0.0
# 54 2021-01-27 23:56:17.705269  0.0  0.0
# C:/Users/enclab01/Desktop/THESIS/Datos Satelitales/goes/diaslajollacloudmask/8351532855/001
#                Dates_and_Hours  BCM  DQF
# 0   2021-02-03 00:01:17.694063  1.0  0.0
# 1   2021-02-03 00:06:17.693936  1.0  0.0
# 2   2021-02-03 00:11:17.693811  1.0  0.0
# 3   2021-02-03 00:16:17.693686  1.0  0.0
# 4   2021-02-03 00:21:17.695367  1.0  0.0
# ..                         ...  ...  ...
# 495 2021-02-04 17:16:17.677649  0.0  0.0
# 496 2021-02-04 17:21:17.677516  0.0  0.0
# 497 2021-02-04 17:26:17.677384  0.0  0.0
# 498 2021-02-04 17:31:17.679058  0.0  0.0
# 499 2021-02-04 17:36:17.678931  0.0  0.0
#
# [500 rows x 3 columns]
# C:/Users/enclab01/Desktop/THESIS/Datos Satelitales/goes/diaslajollacloudmask/8351532856/001
#               Dates_and_Hours  BCM  DQF
# 0  2021-02-04 17:41:17.678806  0.0  0.0
# 1  2021-02-04 17:46:17.678683  0.0  0.0
# 2  2021-02-04 17:51:17.678562  0.0  0.0
# 3  2021-02-04 17:56:17.678442  0.0  0.0
# 4  2021-02-04 18:01:17.680127  0.0  0.0
# ..                        ...  ...  ...
# 67 2021-02-04 23:36:17.695070  0.0  0.0
# 68 2021-02-04 23:41:17.694916  0.0  0.0
# 69 2021-02-04 23:46:17.694768  0.0  0.0
# 70 2021-02-04 23:51:17.694624  0.0  0.0
# 71 2021-02-04 23:56:17.694484  0.0  0.0
#
# [72 rows x 3 columns]
# C:/Users/enclab01/Desktop/THESIS/Datos Satelitales/goes/diaslajollacloudmask/8351532858/001
#                Dates_and_Hours  BCM  DQF
# 0   2021-02-16 00:01:17.672599  1.0  0.0
# 1   2021-02-16 00:06:17.672415  1.0  0.0
# 2   2021-02-16 00:11:17.674038  1.0  0.0
# 3   2021-02-16 00:16:17.673862  1.0  0.0
# 4   2021-02-16 00:21:17.673689  1.0  0.0
# ..                         ...  ...  ...
# 427 2021-02-17 23:36:17.685868  0.0  0.0
# 428 2021-02-17 23:41:17.685654  0.0  0.0
# 429 2021-02-17 23:46:17.685451  0.0  0.0
# 430 2021-02-17 23:51:17.685254  0.0  0.0
# 431 2021-02-17 23:56:17.685059  0.0  0.0
#
# [432 rows x 3 columns]
# C:/Users/enclab01/Desktop/THESIS/Datos Satelitales/goes/diaslajollacloudmask/8351533308/001
#                Dates_and_Hours  BCM  DQF
# 0   2021-03-03 00:01:17.674385  0.0  0.0
# 1   2021-03-03 00:06:17.676098  0.0  0.0
# 2   2021-03-03 00:11:17.676006  0.0  0.0
# 3   2021-03-03 00:16:17.675907  0.0  0.0
# 4   2021-03-03 00:21:17.675805  0.0  0.0
# ..                         ...  ...  ...
# 495 2021-03-04 17:16:17.669538  0.0  0.0
# 496 2021-03-04 17:21:17.669245  0.0  0.0
# 497 2021-03-04 17:26:17.668947  0.0  0.0
# 498 2021-03-04 17:31:17.668642  0.0  0.0
# 499 2021-03-04 17:36:17.668338  0.0  0.0
#
# [500 rows x 3 columns]
# C:/Users/enclab01/Desktop/THESIS/Datos Satelitales/goes/diaslajollacloudmask/8351533713/001
#               Dates_and_Hours  BCM  DQF
# 0  2021-03-04 17:41:17.669844  0.0  0.0
# 1  2021-03-04 17:46:17.669549  0.0  0.0
# 2  2021-03-04 17:51:17.669248  1.0  0.0
# 3  2021-03-04 17:56:17.668940  1.0  0.0
# 4  2021-03-04 18:01:17.668635  1.0  0.0
# 5  2021-03-04 18:06:17.670138  0.0  0.0
# 6  2021-03-04 18:11:17.669840  0.0  0.0
# 7  2021-03-04 18:16:17.669536  0.0  0.0
# 8  2021-03-04 18:21:17.669226  0.0  0.0
# 9  2021-03-04 18:26:17.668917  0.0  0.0
# 10 2021-03-04 18:31:17.670417  0.0  0.0
# 11 2021-03-04 18:36:17.670116  0.0  0.0
# 12 2021-03-04 18:41:17.669807  0.0  0.0
# 13 2021-03-04 18:46:17.669493  0.0  0.0
# 14 2021-03-04 18:51:17.669180  0.0  0.0
# 15 2021-03-04 18:56:17.670678  0.0  0.0
# 16 2021-03-04 19:01:17.670374  0.0  0.0
# 17 2021-03-04 19:06:17.670062  0.0  0.0
# 18 2021-03-04 19:11:17.669746  0.0  0.0
# 19 2021-03-04 19:16:17.669433  0.0  0.0
# 20 2021-03-04 19:21:17.669126  0.0  0.0
# 21 2021-03-04 19:26:17.670628  0.0  0.0
# 22 2021-03-04 19:31:17.670322  0.0  0.0
# 23 2021-03-04 19:36:17.670011  0.0  0.0
# 24 2021-03-04 19:41:17.669702  0.0  0.0
# 25 2021-03-04 19:46:17.669398  0.0  0.0
# 26 2021-03-04 19:51:17.670904  0.0  0.0
# 27 2021-03-04 19:56:17.670612  0.0  0.0
# 28 2021-03-04 20:01:17.670315  0.0  0.0
# 29 2021-03-04 20:06:17.670013  0.0  0.0
# 30 2021-03-04 20:11:17.669712  0.0  0.0
# 31 2021-03-04 20:16:17.671220  0.0  0.0
# 32 2021-03-04 20:21:17.670931  0.0  0.0
# 33 2021-03-04 20:26:17.670649  0.0  0.0
# 34 2021-03-04 20:31:17.670374  0.0  0.0
# 35 2021-03-04 20:36:17.670098  0.0  0.0
# 36 2021-03-04 20:41:17.671618  0.0  0.0
# 37 2021-03-04 20:46:17.671332  0.0  0.0
# 38 2021-03-04 20:51:17.671048  0.0  0.0
# 39 2021-03-04 20:56:17.670768  0.0  0.0
# 40 2021-03-04 21:01:17.670492  0.0  0.0
# 41 2021-03-04 21:06:17.672023  0.0  0.0
# 42 2021-03-04 21:11:17.671756  0.0  0.0
# 43 2021-03-04 21:16:17.671493  0.0  0.0
# 44 2021-03-04 21:21:17.671233  0.0  0.0
# 45 2021-03-04 21:26:17.670977  0.0  0.0
# 46 2021-03-04 21:31:17.670724  0.0  0.0
# 47 2021-03-04 21:46:17.671785  0.0  0.0
# C:/Users/enclab01/Desktop/THESIS/Datos Satelitales/goes/diaslajollacloudmask/8351533873/001
#                Dates_and_Hours  BCM  DQF
# 0   2021-03-10 00:01:17.679012  0.0  0.0
# 1   2021-03-10 00:06:17.678864  0.0  0.0
# 2   2021-03-10 00:11:17.678712  0.0  0.0
# 3   2021-03-10 00:16:17.678571  0.0  0.0
# 4   2021-03-10 00:21:17.678442  0.0  0.0
# ..                         ...  ...  ...
# 495 2021-03-11 17:21:17.669835  1.0  0.0
# 496 2021-03-11 17:26:17.669476  1.0  0.0
# 497 2021-03-11 17:31:17.669115  1.0  0.0
# 498 2021-03-11 17:36:17.668763  0.0  0.0
# 499 2021-03-11 17:41:17.668424  1.0  0.0
#
# [500 rows x 3 columns]
# C:/Users/enclab01/Desktop/THESIS/Datos Satelitales/goes/diaslajollacloudmask/8351533874/001
#               Dates_and_Hours  BCM  DQF
# 0  2021-03-11 17:46:17.669890  1.0  0.0
# 1  2021-03-11 17:51:17.669552  1.0  0.0
# 2  2021-03-11 17:56:17.669210  1.0  0.0
# 3  2021-03-11 18:01:17.668864  1.0  0.0
# 4  2021-03-11 18:06:17.668515  1.0  0.0
# 5  2021-03-11 18:11:17.669965  1.0  0.0
# 6  2021-03-11 18:16:17.669608  1.0  0.0
# 7  2021-03-11 18:21:17.669248  1.0  0.0
# 8  2021-03-11 18:26:17.668884  1.0  0.0
# 9  2021-03-11 18:31:17.668517  1.0  0.0
# 10 2021-03-11 18:36:17.668146  1.0  0.0
# 11 2021-03-11 18:41:17.669577  1.0  0.0
# 12 2021-03-11 18:46:17.669202  1.0  0.0
# 13 2021-03-11 18:51:17.668825  0.0  0.0
# 14 2021-03-11 18:56:17.668445  0.0  0.0
# 15 2021-03-11 19:01:17.668064  0.0  0.0
# 16 2021-03-11 19:06:17.669485  0.0  0.0
# 17 2021-03-11 19:11:17.669100  0.0  0.0
# 18 2021-03-11 19:16:17.668714  0.0  0.0
# 19 2021-03-11 19:21:17.668326  0.0  0.0
# 20 2021-03-11 19:26:17.667946  0.0  0.0
# 21 2021-03-11 19:31:17.669387  0.0  0.0
# 22 2021-03-11 19:36:17.669032  0.0  0.0
# 23 2021-03-11 19:41:17.668679  0.0  0.0
# 24 2021-03-11 19:46:17.668325  0.0  0.0
# 25 2021-03-11 19:51:17.667968  0.0  0.0
# 26 2021-03-11 19:56:17.669412  0.0  0.0
# 27 2021-03-11 20:01:17.669050  0.0  0.0
# 28 2021-03-11 20:06:17.668697  0.0  0.0
# 29 2021-03-11 20:11:17.668359  0.0  0.0
# 30 2021-03-11 20:16:17.668024  0.0  0.0
# 31 2021-03-11 20:21:17.669490  0.0  0.0
# 32 2021-03-11 20:26:17.669150  0.0  0.0
# 33 2021-03-11 20:31:17.668812  0.0  0.0
# 34 2021-03-11 20:36:17.668488  0.0  0.0
# 35 2021-03-11 20:41:17.668168  0.0  0.0
# 36 2021-03-11 20:46:17.667845  0.0  0.0
# 37 2021-03-11 20:51:17.669321  0.0  0.0
# 38 2021-03-11 20:56:17.669005  0.0  0.0
# 39 2021-03-11 21:01:17.668698  0.0  0.0
# 40 2021-03-11 21:06:17.668389  0.0  0.0
# 41 2021-03-11 21:11:17.668078  0.0  0.0
# 42 2021-03-11 21:16:17.669582  0.0  0.0
# 43 2021-03-11 21:21:17.669288  0.0  0.0
# 44 2021-03-11 21:26:17.668992  0.0  0.0
# 45 2021-03-11 21:31:17.668709  0.0  0.0
# 46 2021-03-11 21:41:17.669958  0.0  0.0
# 47 2021-03-11 21:46:17.669693  0.0  0.0
# C:/Users/enclab01/Desktop/THESIS/Datos Satelitales/goes/diaslajollacloudmask/8351533893/001
#                Dates_and_Hours  BCM  DQF
# 0   2021-03-15 00:01:17.681819  0.0  0.0
# 1   2021-03-15 00:06:17.681730  0.0  0.0
# 2   2021-03-15 00:11:17.681651  0.0  0.0
# 3   2021-03-15 00:16:17.681578  0.0  0.0
# 4   2021-03-15 00:21:17.683305  0.0  0.0
# ..                         ...  ...  ...
# 495 2021-03-16 18:36:17.690776  0.0  0.0
# 496 2021-03-16 18:41:17.690469  0.0  0.0
# 497 2021-03-16 18:46:17.690159  0.0  0.0
# 498 2021-03-16 18:51:17.689862  0.0  0.0
# 499 2021-03-16 18:56:17.689572  0.0  0.0
#
# [500 rows x 3 columns]
# C:/Users/enclab01/Desktop/THESIS/Datos Satelitales/goes/diaslajollacloudmask/8351533894/001
#               Dates_and_Hours  BCM  DQF
# 0  2021-03-16 19:01:17.691077  0.0  0.0
# 1  2021-03-16 19:06:17.690771  0.0  0.0
# 2  2021-03-16 19:11:17.690474  0.0  0.0
# 3  2021-03-16 19:16:17.690186  0.0  0.0
# 4  2021-03-16 19:21:17.689890  0.0  0.0
# 5  2021-03-16 19:26:17.691390  0.0  0.0
# 6  2021-03-16 19:31:17.691094  0.0  0.0
# 7  2021-03-16 19:36:17.690812  0.0  0.0
# 8  2021-03-16 19:41:17.690528  0.0  0.0
# 9  2021-03-16 19:46:17.690233  0.0  0.0
# 10 2021-03-16 19:51:17.689942  0.0  0.0
# 11 2021-03-16 19:56:17.691466  0.0  0.0
# 12 2021-03-16 20:01:17.691185  0.0  0.0
# 13 2021-03-16 20:06:17.690892  0.0  0.0
# 14 2021-03-16 20:11:17.690602  0.0  0.0
# 15 2021-03-16 20:16:17.690326  0.0  0.0
# 16 2021-03-16 20:21:17.691861  0.0  0.0
# 17 2021-03-16 20:26:17.691583  0.0  0.0
# 18 2021-03-16 20:31:17.691304  0.0  0.0
# 19 2021-03-16 20:36:17.691034  0.0  0.0
# 20 2021-03-16 20:41:17.690767  0.0  0.0
# 21 2021-03-16 20:46:17.692294  0.0  0.0
# 22 2021-03-16 20:51:17.692020  0.0  0.0
# 23 2021-03-16 20:56:17.691761  0.0  0.0
# 24 2021-03-16 21:01:17.691516  0.0  0.0
# 25 2021-03-16 21:06:17.691270  0.0  0.0
# 26 2021-03-16 21:11:17.692819  0.0  0.0
# 27 2021-03-16 21:16:17.692569  0.0  0.0
# 28 2021-03-16 21:21:17.692333  0.0  0.0
# 29 2021-03-16 21:26:17.692109  0.0  0.0
# 30 2021-03-16 21:31:17.691880  0.0  0.0
# 31 2021-03-16 21:36:17.693454  0.0  0.0
# 32 2021-03-16 21:41:17.693234  0.0  0.0
# 33 2021-03-16 21:46:17.693026  0.0  0.0
# 34 2021-03-16 21:51:17.692821  0.0  0.0
# 35 2021-03-16 21:56:17.692610  1.0  0.0
# 36 2021-03-16 22:01:17.694209  0.0  0.0
# 37 2021-03-16 22:06:17.694018  1.0  0.0
# 38 2021-03-16 22:11:17.693841  0.0  0.0
# 39 2021-03-16 22:16:17.693675  0.0  0.0
# 40 2021-03-16 22:21:17.693504  0.0  0.0
# 41 2021-03-16 22:26:17.693332  0.0  0.0
# 42 2021-03-16 22:31:17.694971  0.0  0.0
# 43 2021-03-16 22:36:17.694817  0.0  0.0
# 44 2021-03-16 22:41:17.694673  0.0  0.0
# 45 2021-03-16 22:46:17.694539  0.0  0.0
# 46 2021-03-16 22:51:17.694416  0.0  0.0
# 47 2021-03-16 22:56:17.696107  0.0  0.0
# 48 2021-03-16 23:01:17.695998  0.0  0.0
# 49 2021-03-16 23:06:17.695882  0.0  0.0
# 50 2021-03-16 23:11:17.695768  0.0  0.0
# 51 2021-03-16 23:16:17.695662  0.0  0.0
# 52 2021-03-16 23:21:17.697370  0.0  0.0
# 53 2021-03-16 23:26:17.697287  0.0  0.0
# 54 2021-03-16 23:31:17.697203  0.0  0.0
# 55 2021-03-16 23:36:17.697114  0.0  0.0
# 56 2021-03-16 23:41:17.697031  0.0  0.0
# 57 2021-03-16 23:46:17.698762  0.0  0.0
# 58 2021-03-16 23:51:17.698701  0.0  0.0
# 59 2021-03-16 23:56:17.698638  0.0  0.0
# C:/Users/enclab01/Desktop/THESIS/Datos Satelitales/goes/diaslajollacloudmask/8351533895/001
#                Dates_and_Hours  BCM  DQF
# 0   2021-03-19 00:01:17.687364  0.0  0.0
# 1   2021-03-19 00:06:17.687347  0.0  0.0
# 2   2021-03-19 00:11:17.687320  0.0  0.0
# 3   2021-03-19 00:16:17.687293  0.0  0.0
# 4   2021-03-19 00:21:17.687272  0.0  0.0
# ..                         ...  ...  ...
# 495 2021-03-20 17:21:17.692807  1.0  0.0
# 496 2021-03-20 17:26:17.692616  1.0  0.0
# 497 2021-03-20 17:31:17.692431  1.0  0.0
# 498 2021-03-20 17:36:17.694054  1.0  0.0
# 499 2021-03-20 17:41:17.693877  1.0  0.0
#
# [500 rows x 3 columns]
# C:/Users/enclab01/Desktop/THESIS/Datos Satelitales/goes/diaslajollacloudmask/8351533896/001
#               Dates_and_Hours  BCM  DQF
# 0  2021-03-20 17:46:17.693688  1.0  0.0
# 1  2021-03-20 17:51:17.693481  1.0  0.0
# 2  2021-03-20 17:56:17.693269  0.0  0.0
# 3  2021-03-20 18:01:17.694862  0.0  0.0
# 4  2021-03-20 18:06:17.694657  0.0  0.0
# ..                        ...  ...  ...
# 70 2021-03-20 23:36:17.703695  0.0  0.0
# 71 2021-03-20 23:41:17.705379  0.0  0.0
# 72 2021-03-20 23:46:17.705267  0.0  0.0
# 73 2021-03-20 23:51:17.705160  0.0  0.0
# 74 2021-03-20 23:56:17.705061  0.0  0.0
#
# [75 rows x 3 columns]
# C:/Users/enclab01/Desktop/THESIS/Datos Satelitales/goes/diaslajollacloudmask/8351533897/001
#                Dates_and_Hours  BCM  DQF
# 0   2021-03-20 00:01:17.695025  0.0  0.0
# 1   2021-03-20 00:06:17.694987  0.0  0.0
# 2   2021-03-20 00:11:17.694956  0.0  0.0
# 3   2021-03-20 00:16:17.694932  0.0  0.0
# 4   2021-03-20 00:21:17.694915  0.0  0.0
# ..                         ...  ...  ...
# 495 2021-03-21 17:16:17.675968  0.0  0.0
# 496 2021-03-21 17:21:17.675773  0.0  0.0
# 497 2021-03-21 17:26:17.675576  0.0  0.0
# 498 2021-03-21 17:31:17.677184  0.0  0.0
# 499 2021-03-21 17:36:17.676990  0.0  0.0
#
# [500 rows x 3 columns]
# C:/Users/enclab01/Desktop/THESIS/Datos Satelitales/goes/diaslajollacloudmask/8351533898/001
#               Dates_and_Hours  BCM  DQF
# 0  2021-03-21 17:41:17.676799  0.0  0.0
# 1  2021-03-21 17:46:17.676610  0.0  0.0
# 2  2021-03-21 17:51:17.676423  0.0  0.0
# 3  2021-03-21 17:56:17.678043  0.0  0.0
# 4  2021-03-21 18:01:17.677863  0.0  0.0
# ..                        ...  ...  ...
# 71 2021-03-21 23:36:17.687778  1.0  0.0
# 72 2021-03-21 23:41:17.687632  0.0  0.0
# 73 2021-03-21 23:46:17.687493  0.0  0.0
# 74 2021-03-21 23:51:17.687361  0.0  0.0
# 75 2021-03-21 23:56:17.687235  0.0  0.0
#
# [76 rows x 3 columns]
# C:/Users/enclab01/Desktop/THESIS/Datos Satelitales/goes/diaslajollacloudmask/8351534086/001
#                Dates_and_Hours  BCM  DQF
# 0   2021-04-02 00:01:17.683481  1.0  0.0
# 1   2021-04-02 00:06:17.683316  1.0  0.0
# 2   2021-04-02 00:11:17.683157  1.0  0.0
# 3   2021-04-02 00:16:17.683003  1.0  0.0
# 4   2021-04-02 00:21:17.684658  1.0  0.0
# ..                         ...  ...  ...
# 262 2021-04-02 21:51:17.761336  0.0  0.0
# 263 2021-04-02 21:56:17.761144  0.0  0.0
# 264 2021-04-02 22:01:17.762754  0.0  0.0
# 265 2021-04-02 22:06:17.762560  0.0  0.0
# 266 2021-04-02 22:16:17.762168  0.0  0.0
#
# [267 rows x 3 columns]
# C:/Users/enclab01/Desktop/THESIS/Datos Satelitales/goes/diaslajollacloudmask/8351534248/001
#               Dates_and_Hours  BCM  DQF
# 0  2021-04-03 17:41:17.689071  0.0  0.0
# 1  2021-04-03 17:46:17.688861  0.0  0.0
# 2  2021-04-03 17:51:17.688651  0.0  0.0
# 3  2021-04-03 17:56:17.690244  0.0  0.0
# 4  2021-04-03 18:01:17.690034  0.0  0.0
# ..                        ...  ...  ...
# 71 2021-04-03 23:36:17.699877  0.0  0.0
# 72 2021-04-03 23:41:17.699694  0.0  0.0
# 73 2021-04-03 23:46:17.699515  0.0  0.0
# 74 2021-04-03 23:51:17.699341  0.0  0.0
# 75 2021-04-03 23:56:17.699172  0.0  0.0
#
# [76 rows x 3 columns]
# C:/Users/enclab01/Desktop/THESIS/Datos Satelitales/goes/diaslajollacloudmask/8351534249/001
#                Dates_and_Hours  BCM  DQF
# 0   2021-04-08 00:01:17.720737  1.0  0.0
# 1   2021-04-08 00:06:17.720596  1.0  0.0
# 2   2021-04-08 00:11:17.722253  1.0  0.0
# 3   2021-04-08 00:16:17.722107  1.0  0.0
# 4   2021-04-08 00:21:17.721957  1.0  0.0
# ..                         ...  ...  ...
# 427 2021-04-09 23:36:17.718404  1.0  0.0
# 428 2021-04-09 23:41:17.718287  0.0  0.0
# 429 2021-04-09 23:46:17.718171  0.0  0.0
# 430 2021-04-09 23:51:17.719854  0.0  0.0
# 431 2021-04-09 23:56:17.719721  0.0  0.0
#
# [432 rows x 3 columns]
# C:/Users/enclab01/Desktop/THESIS/Datos Satelitales/goes/diaslajollacloudmask/8351534250/001
#                Dates_and_Hours  BCM  DQF
# 0   2021-04-09 00:01:17.721007  0.0  0.0
# 1   2021-04-09 00:06:17.720871  0.0  0.0
# 2   2021-04-09 00:11:17.720724  0.0  0.0
# 3   2021-04-09 00:16:17.722367  0.0  0.0
# 4   2021-04-09 00:21:17.722203  1.0  0.0
# ..                         ...  ...  ...
# 427 2021-04-10 23:36:17.715915  1.0  0.0
# 428 2021-04-10 23:41:17.715793  1.0  0.0
# 429 2021-04-10 23:46:17.715666  1.0  0.0
# 430 2021-04-10 23:51:17.717343  1.0  0.0
# 431 2021-04-10 23:56:17.717208  1.0  0.0
#
# [432 rows x 3 columns]
# C:/Users/enclab01/Desktop/THESIS/Datos Satelitales/goes/diaslajollacloudmask/8351534251/001
#                Dates_and_Hours  BCM  DQF
# 0   2021-04-15 00:01:17.709404  1.0  0.0
# 1   2021-04-15 00:06:17.709218  1.0  0.0
# 2   2021-04-15 00:11:17.709031  0.0  0.0
# 3   2021-04-15 00:16:17.708844  0.0  0.0
# 4   2021-04-15 00:21:17.710453  0.0  0.0
# ..                         ...  ...  ...
# 427 2021-04-16 23:36:17.706701  0.0  0.0
# 428 2021-04-16 23:41:17.706530  0.0  0.0
# 429 2021-04-16 23:46:17.706353  0.0  0.0
# 430 2021-04-16 23:51:17.706179  0.0  0.0
# 431 2021-04-16 23:56:17.707807  0.0  0.0
#
# [432 rows x 3 columns]

# %%
"THE REST IS NOT USEFUL RIGHT NOW"
# Out:
# 'THE REST IS NOT USEFUL RIGHT NOW'

# %%
d
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 d
#
# NameError: name 'd' is not defined

# %% [markdown]
# # VISUALIZE DATA

# %%
from scipy.signal import find_peaks
from scipy.signal import find_peaks, savgol_filter

indicess = find_peaks(BCM_values, height=0.00002, prominence=(None, 4000), width=(0.000002, 4000),  rel_height=1)

index=indicess[0]

pir=[]
widths=[]
for m in np.arange(0,len(indicess[1]['peak_heights'])):
    pir.append([indicess[0][m],indicess[1]['prominences'][m],indicess[1]['peak_heights'][m],abs(indicess[1]['right_ips'][m]-indicess[1]['left_ips'][m])])
    widths.append(indicess[1]['widths'][m])    




# Aplicar el filtro Savitzky-Golay para suavizar la señal
smoothed_signal = savgol_filter(DQF_values, window_length=5, polyorder=2)  # Ajusta los parámetros según tus necesidades
# Encontrar los picos en la señal suavizada
peaks2, _ = find_peaks(smoothed_signal, height=0.5)


# Calcular la derivada
derivative = np.gradient(DQF_values)
# Agregar un cero al principio y al final de la derivada para mantener la dimensión
derivative_full = np.concatenate(([0], derivative))



#Transform a list into a data column
df = pd.DataFrame({'col':DQF_values})
dqfvalues=df['col']
rolling=dqfvalues.rolling(3,center=True).mean()


fig, ax = plt.subplots(1)
fig.autofmt_xdate()
plt.plot(time, BCM_values,'-.',c='black') 
#plt.plot(time, derivative,'-.',c='red') 
#plt.plot(time, rolling,'-.',c='purple') 
 
plt.ylabel('BCM Measurements')
xfmt = mdates.DateFormatter('%b %d %H:%M')
ax.xaxis.set_major_formatter(xfmt)


zz=[time[j] for j in index]
zzz=[BCM_values[j] for j in index]

plt.plot(zz,zzz,'x',color='red')

# %% [markdown]
# CLOUD DETECTION ALGORITHM

# %%
import numpy as np
from scipy.signal import find_peaks
from datetime import datetime, timedelta
from scipy.signal import find_peaks, savgol_filter





time_data=time
signal_data=DQF_values

# Encontrar los picos en la señal
peaks, _ = find_peaks(signal_data, width=1 ,height=1)  # Ajusta el umbral según tus necesidades
# Aplicar el filtro Savitzky-Golay para suavizar la señal
smoothed_signal = savgol_filter(signal_data, window_length=5, polyorder=2)  # Ajusta los parámetros según tus necesidades
# Encontrar los picos en la señal suavizada
peaks2, _ = find_peaks(smoothed_signal, height=0.5)




# Calcular el ancho de los picos en formato de tiempo
peak_widths = []
for peak_index in peaks:
    start_peak = peak_index
    while start_peak > 0 and signal_data[start_peak - 1] < signal_data[start_peak]:
        start_peak -= 1
    end_peak = peak_index
    while end_peak < n_points - 1 and signal_data[end_peak + 1] < signal_data[end_peak]:
        end_peak += 1
    width = time_data[end_peak] - time_data[start_peak]
    peak_widths.append(width)

# Imprimir los anchos de los picos en formato de tiempo
for idx, width in enumerate(peak_widths):
    print(f"Pico {idx + 1}: Ancho = {width}")

# %%
import numpy as np
from scipy.signal import find_peaks, savgol_filter
from datetime import datetime, timedelta
import matplotlib.pyplot as plt

# Simulación de datos de tiempo y señales
np.random.seed(0)
n_points = 100
time_interval = timedelta(minutes=10)
start_time = datetime(2023, 8, 1)

time_data = [start_time + i * time_interval for i in range(n_points)]
signal_data = np.random.rand(n_points)

# Aplicar el filtro Savitzky-Golay para suavizar la señal
smoothed_signal = savgol_filter(signal_data, window_length=5, polyorder=2)  # Ajusta los parámetros según tus necesidades

# Encontrar los picos en la señal suavizada
peaks, _ = find_peaks(smoothed_signal, height=0.5)

# Calcular el ancho de los picos en formato de tiempo
peak_widths = []
for peak_index in peaks:
    start_peak = peak_index
    while start_peak > 0 and smoothed_signal[start_peak - 1] < smoothed_signal[start_peak]:
        start_peak -= 1
    end_peak = peak_index
    while end_peak < n_points - 1 and smoothed_signal[end_peak + 1] < smoothed_signal[end_peak]:
        end_peak += 1
    width = time_data[end_peak] - time_data[start_peak]
    peak_widths.append(width)

# Visualizar la señal original, la señal suavizada y los picos encontrados
plt.figure(figsize=(10, 6))
plt.plot(time_data, signal_data, label='Señal Original')
plt.plot(time_data, smoothed_signal, label='Señal Suavizada')

plt.xlabel('Tiempo')
plt.ylabel('Valor de la Señal')
plt.title('Detección de Picos y Señal Suavizada')
plt.legend()
plt.show()

# Imprimir los anchos de los picos en formato de tiempo
for idx, width in enumerate(peak_widths):
    print(f"Pico {idx + 1}: Ancho = {width}")

# %%
plt.figure()
plt.plot(np.arange(0,len(DQF_values)), DQF_values,'.')

# %%
plt.figure()
plt.plot(np.arange(0,len(valuess)), valuess)
plt.figure()
plt.plot(fechas_convertidas, valuess,'.')

# %%
plt.figure()
plt.imshow(cloud_list[0])

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation


# Función para inicializar la animación
def init():
    pass

# Función para actualizar cada cuadro de la animación
def update(frame):
    plt.clf()  # Limpiar el gráfico
    
    plt.imshow(cloud_list[frame], cmap='viridis',vmin=0,vmax=16)  # Ingresar el rango de valores admitidos 
    plt.title(f'Frame {frame + 1}/{len(cloud_list)}')
    plt.colorbar(label='DQF Measurement')
    
    # Agregar un subtítulo
    plt.text(0.5, -0.3, str(fechas_convertidas[frame]), transform=plt.gca().transAxes, ha='center')

    
  

# Crear la figura
fig = plt.figure()

intervalo=200  # En milisegundos

# Crear la animación
ani = animation.FuncAnimation(fig, update, frames=len(cloud_list), init_func=init, blit=False, interval=intervalo)

# Mostrar la animación
plt.show()


f = r"C:/Users/enclab01/Desktop/animation2.gif" 
writergif = animation.PillowWriter(fps=30) 
ani.save(f, writer=writergif)

# %%
import matplotlib.animation as animation

print(animation.writers.list())

# %%
plt.figure()
#plt.plot(np.arange(0,len(time_diff)), time_diff)
plt.plot(np.arange(0,len(time_list)), fechas_convertidas,'x')
plt.xlabel('Evento')
plt.ylabel('Tiempo de muestreo (min)')

# %%
from datetime import datetime, timedelta

# Definir la fecha de inicio (fecha X)
fecha_inicio = datetime(2000, 1, 1, 12, 0, 0)

# Datos de tiempo en segundos
datos_en_segundos = [123, 3600, 86400]  # Ejemplo de datos en segundos

# Convertir los datos en segundos a formato de fecha
fechas_convertidas = []

for tiempo_segundos in datos_en_segundos:
    delta = timedelta(seconds=tiempo_segundos)
    fecha_convertida = fecha_inicio + delta
    fechas_convertidas.append(fecha_convertida)

# Imprimir las fechas convertidas
for fecha in fechas_convertidas:
    print(fecha)

# %%
print(time_list)

# %%
ysize=13

ax1=plt.subplot(1,1,1)
plt.plot(np.arange(1,len(cloud_list)+1),cloud_list,'-x')
ax1.tick_params(axis="y", labelsize=ysize, labelcolor='black')
ax1.tick_params(axis="x", labelsize=ysize, labelcolor='black')  
plt.ylabel('Cloud Fraction (%)',fontsize=ysize,color='black')  
plt.xlabel('Time (day)',fontsize=ysize,color='black') 
plt.title('Cloud Fraction California: ('+str(latitud)+','+str(longitud)+')', fontsize=15)

# %%
import GOES

ds = GOES.open_dataset('C:/Users/enclab01/Desktop/THESIS/Datos Satelitales/goes/8333321207/001/OR_ABI-L2-CMIPC-M6C06_G16_s20232240001172_e20232240003551_c20232240004021.nc')



CMI, LonCen, LatCen = ds.image('CMI', lonlat='center')
x, y = GOES.find_pixel_of_coordinate(LonCen, LatCen, 33.2, -119.5)
print(CMI.data[y,x])

# CMI.time_bounds.data[0].strftime('%Y/%m/%d %H:%M UTC')
print(CMI.time_bounds.data[0])
